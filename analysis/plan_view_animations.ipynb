# %%
#Packages 
import numpy as np
import cartopy
import glob
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature
import cmocean.cm as cmo
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import warnings
import xarray as xr
import os
import xroms
from glob import glob
from joblib import Parallel, delayed
warnings.filterwarnings("ignore") #turns off annoying warnings
# Out:
# /global/u2/d/dylan617/miconda3/envs/xroms/lib/python3.12/site-packages/esmpy/interface/loadESMF.py:94: VersionWarning: ESMF installation version 8.8.0, ESMPy version 8.8.0b0
#   warnings.warn("ESMF installation version {}, ESMPy version {}".format(

# %%
# === Paths ===
grd_file = '/pscratch/sd/d/dylan617/beaufort_roms/runs_idealized/inputs/grd.nc'
his_file = '/pscratch/sd/d/dylan617/beaufort_roms/runs_idealized/outputs/roms_his_ice*.nc'

# === Load datasets ===
dsg = xr.open_dataset(grd_file)
ds = xroms.open_mfnetcdf(glob(his_file))
ds, grid = xroms.roms_dataset(ds)

# %%
def to_rho(var):
    if var.dims[-1] != 'xi_rho':
        var = grid.interp(var, 'X', to='center', boundary='extend')
    if var.dims[-2] != 'eta_rho':
        var = grid.interp(var, 'Y', to='center', boundary='extend')
    return var

def velgrad(ds,grid):
    '''
    Calculates flow invariants vorticity, divergence, strain
    '''
    us = ds.u 
    vs = ds.v

    dudx = grid.derivative(us, 'X', boundary='extend')
    dvdy = grid.derivative(vs, 'Y', boundary='extend')
    dudy = to_rho(grid.derivative(us, 'Y', boundary='extend'))
    dvdx = to_rho(grid.derivative(vs, 'X', boundary='extend'))
    # Vorticity:  v_x - u_y
    rv = (dvdx - dudy)/ds.f
    rv.name = 'Normalized vorticity'

    # Divergence: u_x + v_y
    delta = (dudx + dvdy)/ds.f
    delta.name = 'Normalized divergence'

    # Major axis of deformation
    alpha = ( np.sqrt( (dudx-dvdy)**2 + (dvdx+dudy)**2 ) )/ds.f
    alpha.name = 'Normalized strain'
    
    return rv,delta,alpha

rv,delta,alpha = velgrad(ds,grid)

# %%
# Convert to km
xrho = dsg.x_rho / 1000
xu = dsg.x_u / 1000
yrho = dsg.y_rho / 1000 
yu = dsg.y_u / 1000
print(ds.ocean_time[-1].values)
# Out:
# 0001-02-21 10:00:00

# %%
tidx = -1 
temp = ds.temp[tidx,-1]
salt = ds.salt[tidx,-1]
zeta = rv[tidx,-1]
aice = ds.Aice[tidx]

nrows = 2; ncols = 2
fig, ax = plt.subplots(nrows, ncols, figsize=((9.75/3)*1.9, 5),
                       constrained_layout=True, 
                       sharex=True, sharey=True, dpi=300)


# Temperature
m = ax[0,0].pcolormesh(xrho, yrho, temp, cmap='RdYlBu_r', vmin = -1.8, vmax = 1.8)
fig.colorbar(m, ax=ax[0,0], label='[C]', extend='both')

# Salinity
m1 = ax[0,1].pcolormesh(xrho, yrho, salt, cmap=cmo.haline)
fig.colorbar(m1, ax=ax[0,1], label='[g/kg]', extend='both')

# Relative vorticity
m2 = ax[1,0].pcolormesh(xrho, yrho, zeta, cmap=cmo.balance,
                      vmin = -1.5, vmax = 1.5)
fig.colorbar(m2, ax=ax[1,0], label='$(\partial_x v - \partial_y u)/f$', extend='both')

# Ice area fraction, aka concentration
m3 = ax[1,1].pcolormesh(xrho, yrho, aice, cmap=cmo.amp,
                      vmin = 0, vmax = 0.5)
fig.colorbar(m3, ax=ax[1,1], label='[]', extend='max')

# Set consistent axis limits
for i in range(nrows):
    for j in range(ncols):
        ax[i,j].set_xlabel('Along-shelf distance [km]')
        ax[i,j].set_aspect(0.8)

ax[0,0].set_ylabel('Across-shelf distance [km]')
ax[1,0].set_ylabel('Across-shelf distance [km]')
ax[0,0].set_title('Surface temperature')
ax[0,0].set_xlabel('')
ax[0,1].set_xlabel('')
ax[0,1].set_title('Surface salinity')
ax[1,0].set_title(r'Surface $\zeta/f$')
ax[1,1].set_title(r'Ice concentration')
fig.suptitle(str(ds.ocean_time.values[tidx])[:10])
# Out:
# Text(0.5, 0.98, '0001-02-21')

# %%
def plot_frame(tidx):

    nrows = 2; ncols = 2
    fig, ax = plt.subplots(nrows, ncols, figsize=((9.75/3)*1.9, 5),
                        constrained_layout=True, 
                        sharex=True, sharey=True, dpi=300)

    i = tidx // 1
    temp = ds.temp[tidx,-1]
    salt = ds.salt[tidx,-1]
    zeta = rv[tidx,-1]
    aice = ds.Aice[tidx]
    # Temperature
    m = ax[0,0].pcolormesh(xrho, yrho, temp, cmap='RdYlBu_r', vmin = -1.8, vmax = 1.8)
    fig.colorbar(m, ax=ax[0,0], label='[C]', extend='both')

    # Salinity
    m1 = ax[0,1].pcolormesh(xrho, yrho, salt, cmap=cmo.haline)
    fig.colorbar(m1, ax=ax[0,1], label='[g/kg]', extend='both')

    # Relative vorticity
    m2 = ax[1,0].pcolormesh(xrho, yrho, zeta, cmap=cmo.balance,
                        vmin = -1.5, vmax = 1.5)
    fig.colorbar(m2, ax=ax[1,0], label='$(\partial_x v - \partial_y u)/f$', extend='both')

    # Ice area fraction, aka concentration
    m3 = ax[1,1].pcolormesh(xrho, yrho, aice, cmap=cmo.amp,
                        vmin = 0, vmax = 0.5)
    fig.colorbar(m3, ax=ax[1,1], label='[]', extend='max')

    # Set consistent axis limits
    for j in range(nrows):
        for k in range(ncols):
            ax[j,k].set_xlabel('Along-shelf distance [km]')
            ax[j,k].set_aspect(0.8)

    ax[0,0].set_ylabel('Across-shelf distance [km]')
    ax[1,0].set_ylabel('Across-shelf distance [km]')
    ax[0,0].set_title('Surface temperature')
    ax[0,0].set_xlabel('')
    ax[0,1].set_xlabel('')
    ax[0,1].set_title('Surface salinity')
    ax[1,0].set_title(r'Surface $\zeta/f$')
    ax[1,1].set_title(r'Ice concentration')
    fig.suptitle(str(ds.ocean_time.values[tidx])[:10])

        # Comment this out if you are printing a lot of frames... jupyter will be unhappy
    print(f'/pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_{i}.png')
   
    plt.savefig(
        f'/pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_{i}.png',
        dpi=200, bbox_inches='tight'
    )
    plt.close(fig)  # Close to avoid memory leaks

# Run 8 plots in parallel at once (adjust n_jobs based on your CPU). If you did this on a compute node you can set it to be 128!!
Parallel(n_jobs=4)(delayed(plot_frame)(tidx) for tidx in range(0, len(ds.ocean_time), 1))
# Out:
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_0.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_1.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_2.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_3.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_4.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_5.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_6.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_7.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_8.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_9.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_10.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_11.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_12.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_13.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_14.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_15.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_16.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_17.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_18.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_20.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_21.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_22.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_23.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_25.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_19.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_28.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_24.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_29.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_26.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_30.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_31.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_32.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_33.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_34.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_27.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_35.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_36.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_37.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_38.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_39.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_40.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_41.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_42.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_43.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_44.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_45.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_46.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_47.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_48.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_49.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_50.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_52.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_51.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_53.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_54.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_56.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_57.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_55.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_59.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_58.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_60.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_61.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_62.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_63.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_64.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_65.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_66.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_67.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_68.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_69.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_70.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_71.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_72.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_73.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_74.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_76.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_77.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_79.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_75.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_78.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_82.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_83.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_80.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_84.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_85.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_81.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_86.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_87.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_88.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_89.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_90.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_91.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_92.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_93.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_94.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_95.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_96.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_97.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_98.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_99.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_100.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_101.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_102.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_103.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_105.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_107.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_109.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_104.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_106.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_111.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_112.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_108.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_113.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_114.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_115.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_116.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_117.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_118.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_119.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_110.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_120.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_121.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_123.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_124.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_125.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_127.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_128.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_129.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_130.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_132.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_122.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_134.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_126.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_135.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_136.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_137.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_138.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_131.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_139.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_140.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_141.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_142.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_143.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_133.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_144.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_145.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_146.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_147.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_149.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_150.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_151.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_152.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_153.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_154.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_155.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_156.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_158.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_160.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_148.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_162.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_163.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_157.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_164.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_165.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_159.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_167.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_168.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_169.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_170.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_161.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_171.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_172.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_173.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_174.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_175.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_176.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_177.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_178.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_166.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_180.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_181.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_182.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_183.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_185.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_186.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_187.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_188.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_189.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_179.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_191.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_193.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_192.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_194.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_184.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_196.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_197.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_198.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_199.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_200.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_201.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_190.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_202.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_203.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_204.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_205.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_195.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_208.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_209.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_210.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_211.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_212.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_213.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_214.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_215.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_216.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_207.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_206.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_218.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_220.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_221.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_222.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_223.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_224.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_225.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_226.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_227.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_217.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_228.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_230.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_219.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_231.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_233.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_234.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_235.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_236.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_237.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_238.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_239.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_240.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_229.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_241.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_242.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_243.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_244.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_232.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_245.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_247.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_249.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_250.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_251.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_252.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_253.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_254.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_256.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_257.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_246.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_248.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_258.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_259.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_260.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_261.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_262.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_263.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_264.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_266.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_255.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_267.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_268.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_269.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_270.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_271.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_272.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_273.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_274.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_275.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_276.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_277.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_280.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_265.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_281.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_282.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_283.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_284.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_285.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_287.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_278.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_288.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_279.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_289.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_290.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_292.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_293.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_294.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_295.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_296.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_286.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_297.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_298.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_299.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_300.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_301.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_304.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_291.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_305.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_306.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_307.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_308.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_309.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_310.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_311.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_312.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_302.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_303.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_314.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_315.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_316.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_317.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_319.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_320.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_321.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_322.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_323.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_324.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_325.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_313.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_327.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_318.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_329.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_330.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_331.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_332.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_333.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_334.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_335.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_336.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_337.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_326.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_328.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_338.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_339.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_340.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_341.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_342.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_345.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_346.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_347.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_349.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_350.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_351.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_352.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_343.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_344.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_353.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_355.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_356.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_348.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_357.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_358.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_359.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_360.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_361.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_362.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_363.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_364.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_365.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_366.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_367.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_368.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_369.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_354.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_370.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_372.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_374.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_376.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_377.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_378.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_371.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_373.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_375.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_380.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_381.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_382.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_383.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_384.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_385.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_386.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_387.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_388.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_389.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_390.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_391.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_392.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_379.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_393.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_394.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_396.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_397.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_398.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_399.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_400.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_401.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_402.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_403.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_404.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_406.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_395.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_409.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_410.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_411.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_405.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_412.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_407.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_413.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_414.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_415.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_416.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_408.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_418.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_419.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_420.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_421.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_422.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_423.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_424.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_425.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_426.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_427.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_428.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_430.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_432.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_417.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_433.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_435.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_436.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_429.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_437.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_431.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_438.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_439.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_440.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_441.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_442.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_443.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_444.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_434.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_445.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_446.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_448.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_449.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_450.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_451.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_452.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_453.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_455.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_457.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_447.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_459.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_460.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_454.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_461.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_456.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_462.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_463.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_465.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_464.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_466.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_467.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_468.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_458.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_469.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_470.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_471.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_472.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_474.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_473.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_475.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_476.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_477.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_479.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_480.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_478.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_481.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_484.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_485.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_482.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_486.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_483.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_487.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_488.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_489.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_490.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_491.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_492.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_493.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_494.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_495.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_496.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_497.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_498.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_499.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_500.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_502.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_504.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_501.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_503.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_507.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_505.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_508.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_509.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_510.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_506.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_511.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_512.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_513.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_514.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_515.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_516.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_517.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_518.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_519.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_520.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_521.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_522.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_523.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_524.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_525.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_526.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_527.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_528.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_529.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_530.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_532.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_533.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_534.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_535.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_531.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_539.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_536.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_537.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_540.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_541.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_538.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_542.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_543.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_544.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_545.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_546.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_547.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_548.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_549.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_550.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_551.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_553.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_554.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_555.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_556.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_557.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_552.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_561.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_558.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_562.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_559.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_563.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_564.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_560.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_565.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_566.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_567.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_568.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_569.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_570.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_571.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_572.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_573.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_576.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_577.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_578.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_579.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_580.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_582.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_583.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_584.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_574.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_575.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_585.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_586.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_587.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_588.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_589.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_581.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_591.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_592.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_593.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_594.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_595.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_596.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_597.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_598.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_599.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_600.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_602.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_603.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_590.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_606.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_607.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_608.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_601.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_609.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_610.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_604.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_612.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_605.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_613.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_614.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_615.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_616.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_617.png
# /pscratch/sd/d/dylan617/beaufort_roms/animations/idealized/with_ice/plan_view_611.png
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
